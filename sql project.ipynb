# %%
import pandas as pd

# Replace 'ChicagoCensusDatacsv' with the actual file path
file_path = 'ChicagoCensusData .csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame (table)
df
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
import pandas as pd


file_path = 'ChicagoCrimeData .csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame (table)
df
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
import pandas as pd


file_path = 'ChicagoPublicSchools.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame (table)
df
# Out:
#      School_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School         Street_Address     City State  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
import pandas as pd
from pandasql import sqldf

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCensusData .csv')

# SQL query to select community areas with per capita income less than 11000
query = "SELECT community_area_name FROM df WHERE per_capita_income < 11000;"

# Execute the query
result = sqldf(query)

# Display the result
print(result)
# Out:
#   COMMUNITY_AREA_NAME
# 0  West Garfield Park
# 1      South Lawndale
# 2         Fuller Park
# 3           Riverdale

# %%
import pandas as pd
from pandasql import sqldf

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCrimeData .csv')

# SQL query to find the total number of cases
query = "SELECT SUM(case_number) as total_cases FROM df;"

# Execute the query
result = sqldf(query)

print(f'The total number of cases recorded is: {result["total_cases"].values[0]}')
# Out:
# The total number of cases recorded is: 0.0

# %%
import pandas as pd
from pandasql import sqldf

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCrimeData .csv')

# SQL query to select case numbers for kidnapping crimes
query = "SELECT case_number from df WHERE primary_type is 'kidnapping';"

# Execute the query
result = sqldf(query)

# Display the result
print(result)
# Out:
# Empty DataFrame
# Columns: [CASE_NUMBER]
# Index: []

# %%
import pandas as pd
from pandasql import sqldf

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCrimeData .csv')

# SQL-like query to select crimes recorded at schools
query = "SELECT * FROM df WHERE LOWER(location_description) LIKE '%school%';"

# Execute the query
school_crimes = sqldf(query)

# Display the result
print(school_crimes)
# Out:
#           ID CASE_NUMBER        DATE                                BLOCK  \
# 0    4006321    HL353697  2005-05-04                  077XX S BURNHAM AVE
# 1    4430638    HL725506  2005-11-09                048XX N FRANCISCO AVE
# 2    6644618    HP716225  2008-12-04  030XX S DR MARTIN LUTHER KING JR DR
# 3    2341955    HH639427  2002-09-10                   005XX N WALLER AVE
# 4   11110571    JA460432  2017-10-05                    076XX S HOMAN AVE
# 5    7399281    HS200939  2010-03-10                053XX W CONGRESS PKWY
# 6    3530721    HK577020  2004-08-23                  016XX W JONQUIL TER
# 7    7502426    HS305355  2010-05-13                035XX S WASHTENAW AVE
# 8    8082600    HT315369  2011-05-26                     032XX W ADAMS ST
# 9    7174283    HR585012  2009-10-13                      043XX W 79TH ST
# 10   2075734    HH292682  2002-04-05                 016XX W BRYN MAWR AV
# 11   1806896     G635735  2001-10-22                 0000X N HERMITAGE AV
#
# ...

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCrimeData .csv')

# SQL-like query to select unique crime types recorded at schools
query = """
    SELECT DISTINCT primary_type
    FROM df
    WHERE LOWER(location_description) LIKE '%school%';
"""

# Execute the query
unique_crime_types_at_schools = sqldf(query)

# Display the result
print(unique_crime_types_at_schools)
# Out:
#              PRIMARY_TYPE
# 0                 BATTERY
# 1         CRIMINAL DAMAGE
# 2               NARCOTICS
# 3                 ASSAULT
# 4       CRIMINAL TRESPASS
# 5  PUBLIC PEACE VIOLATION

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoPublicSchools.csv')

# SQL-like query to calculate the average safety score for each school type
query = """
    SELECT school_id, (safety_icon) AS safety_icon
    FROM df
    GROUP BY school_id;
"""

# Execute the query
average_safety_icon_by_id = sqldf(query)

# Display the result
print(average_safety_icon_by_id)
# Out:
#      School_ID  safety_icon
# 0       400018         Weak
# 1       609674         Weak
# 2       609676         Weak
# 3       609678  Very Strong
# 4       609679      Average
# ..         ...          ...
# 561     610539      Average
# 562     610541      Average
# 563     610542       Strong
# 564     610543       Strong
# 565     610544      Average
#
# [566 rows x 2 columns]

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoPublicSchools.csv')

# SQL-like query to calculate the average safety score for each school ID
query = """
    SELECT school_id, AVG(safety_score) AS avg_safety_score
    FROM df
    GROUP BY school_id;
"""

# Execute the query
average_safety_score_by_id = sqldf(query)

# Display the result
print(average_safety_score_by_id)
# Out:
#      School_ID  avg_safety_score
# 0       400018              38.0
# 1       609674              27.0
# 2       609676              29.0
# 3       609678              92.0
# 4       609679              59.0
# ..         ...               ...
# 561     610539              54.0
# 562     610541              53.0
# 563     610542              67.0
# 564     610543              67.0
# 565     610544              54.0
#
# [566 rows x 2 columns]

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCensusData .csv')

# SQL-like query to calculate the poverty rate and select the top 5 community areas
query = """
    SELECT community_area_name, 
           AVG(PERCENT_HOUSEHOLDS_BELOW_POVERTY * 100) AS percent_households_below_poverty
    FROM df
    GROUP BY community_area_name
    ORDER BY percent_households_below_poverty DESC
    LIMIT 5;
"""

# Execute the query
top_poverty_areas = sqldf(query)

# Display the result
print(top_poverty_areas)
# Out:
#   COMMUNITY_AREA_NAME  percent_households_below_poverty
# 0           Riverdale                            5650.0
# 1         Fuller Park                            5120.0
# 2           Englewood                            4660.0
# 3      North Lawndale                            4310.0
# 4  East Garfield Park                            4240.0

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCrimeData .csv')

# SQL-like query to find the community area with the highest number of crimes
query = """
    SELECT community_area_number, COUNT(*) AS crime_count
    FROM df
    GROUP BY community_area_number
    ORDER BY crime_count DESC
    LIMIT 1;
"""

# Execute the query
most_crime_prone_area = sqldf(query)

# Display the result
print(most_crime_prone_area)
# Out:
#    COMMUNITY_AREA_NUMBER  crime_count
# 0                   25.0           43

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCensusData .csv')

# SQL-like query with a subquery to find the name of the community area with the highest hardship index
query = """
    SELECT community_area_name
    FROM df
    WHERE hardship_index = (
        SELECT MAX(hardship_index)
        FROM df
    );
"""

# Execute the query
community_area_with_highest_hardship_index = sqldf(query)

# Display the result
print(community_area_with_highest_hardship_index)
# Out:
#   COMMUNITY_AREA_NAME
# 0           Riverdale

# %%
from pandasql import sqldf
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('ChicagoCrimeData .csv')

# SQL-like query with a subquery to find the Community Area Name with the most number of crimes
query = """
    SELECT community_area_number
    FROM df
    WHERE iucr = (
        SELECT MAX(iucr)
        FROM df
    );
"""

# Execute the query
community_area_with_most_crimes = sqldf(query)

# Display the result
print(community_area_with_most_crimes)
# Out:
#   COMMUNITY_AREA_NUMBER
# 0                  None

# %%
# %sql select count(*) from ChicagoCrimeData .csv
# Out:
# UsageError: Line magic function `%sql` not found.
